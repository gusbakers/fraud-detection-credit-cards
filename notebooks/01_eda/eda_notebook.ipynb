# %% [markdown]
# # Exploratory Data Analysis
# This notebook starts with a simple example to load the fraud dataset and inspect its shape.

# %%
import pandas as pd

# Replace with your actual dataset path
df = pd.read_csv('../../src/data/placeholder.csv')
print(df.shape)
df.head()
